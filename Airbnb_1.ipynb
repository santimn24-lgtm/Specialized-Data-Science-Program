# %% [markdown]
# ![imagen](Airbnb.png)

# %% [markdown]
# # Exercise 1
#
# In order to begin the process of characterizing the various accommodations available on Airbnb in the city of Amsterdam, the following hypotheses are of interest:
#
# 1. 53% of the review scores for listings on the Airbnb platform fall between 20 and 96 points.
#
# 2. The average rental price for a property that is above the 78th percentile of city prices is 300 euros.
#
# 3. 20% of properties in the city are being rented for less than the Amsterdam city average.
#
# 4. Alberto claims to have rented a property on the Airbnb platform for 130 euros, which is one standard deviation above the average.

# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2. Load data

# %%
data= pd.read_csv('listings_m-2-.csv', sep=',')
data.head()
# Out:
#       id                         listing_url     scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  2.021040e+13   12/04/2021
# 1  20168  https://www.airbnb.com/rooms/20168  2.021040e+13   12/04/2021
# 2  25428  https://www.airbnb.com/rooms/25428  2.021040e+13   11/04/2021
# 3  27886  https://www.airbnb.com/rooms/27886  2.021040e+13   11/04/2021
# 4  28871  https://www.airbnb.com/rooms/28871  2.021040e+13   13/04/2021
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1       Studio with private bathroom in the centre 1
# 2  Lovely, 1 bed apt in Ctr (w.lift) -3/20-6/20(f...
# 3  Romantic, stylish B&B houseboat in canal district
# 4                            Comfortable double room
#
#                                          description  \
# 0  Quiet Garden View Room & Super Fast WiFi<br />...
# 1  17th century Dutch townhouse in the heart of t...
# ...

# %%
data = data[['price', 'review_scores_rating']]
data.head()
# Out:
#    price  review_scores_rating
# 0     59                  98.0
# 1    200                  89.0
# 2    125                 100.0
# 3    141                  99.0
# 4     75                  97.0

# %%
data.dtypes
# Out:
# price                     int64
# review_scores_rating    float64
# dtype: object

# %% [markdown]
# # 3. Hypothesis testing

# %% [markdown]
# #### 1. 53% of the review scores for listings on the Airbnb platform fall between 20 and 96 points.

# %%
#Use loc to find how many dates are between 20 - 96
between_20_96 = data.loc[(data['review_scores_rating'] >= 20) & (data['review_scores_rating'] <= 96)]
percentage = len(between_20_96) / len(data) * 100
print(f"Percentage between 20 and 96: {porcentaje:.2f}%")
# Out:
# Percentage between 20 and 96: 66.13%

# %% [markdown]
# #### The percentage between 20 and 96 is 38.39%, not 53%

# %% [markdown]
# #### 2. The average rental price for a property that is above the 78th percentile of city prices is 300 euros.

# %%
price_78 = data['price'].quantile(0.78)
average_above_78 = data.loc[data['price'] > price_78, 'price'].mean()
print(f"Price at 78th percentile: {price_78:.2f}")
print(f"Average price above 78th percentile: {average_above_78:.2f}")
# Out:
# Price at 78th percentile: 195.00
# Average price above 78th percentile: 300.76

# %% [markdown]
# #### The hypothesis is correct: the average price for over 78% of the data points is 300.

# %% [markdown]
# #### 3. 20% of properties in the city are being rented for less than the Amsterdam city average.

# %%
mean_price = data['price'].mean()
below_mean = data.loc[data['price'] < mean_price]
percentage = len(below_mean) / len(data) * 100

print(f"The mean is: {mean_price:.2f}")
print(f"Count below mean: {len(below_mean)}")
print(f"The percentage of rental income below the average is: {percentage:.2f}%")
# Out:
# The mean is: 154.50
# Count below mean: 11788
# The percentage of rental income below the average is: 66.13%

# %% [markdown]
# #### The statement is NOT TRUE. The actual percentage is 66.13%, which means the distribution is skewed to the right.

# %% [markdown]
# #### 4. Alberto claims to have rented a property on the Airbnb platform for 130 euros, which is one standard deviation above the average.

# %%
std_price = data['price'].std()

one_std_above = mean_price + std_price

print(f"Mean + 1 std: {one_std_above:.2f}")
# Out:
# Mean + 1 std: 308.66

# %% [markdown]
# #### The statement is false for two reasons: first, the mean is 154, so 130 cannot be one standard deviation above it; and second, one standard deviation above the mean is equal to 308.
